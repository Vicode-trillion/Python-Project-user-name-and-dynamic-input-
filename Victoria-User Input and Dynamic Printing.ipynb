# %% [markdown]
# Hello and welcome! What you are about to read is not a story that was planned.
#
# It was assembled from fragments, the way all real discoveries are. Five strangers, one signal, and a device that already knew their names. This is a thriller set in a future that feels closer than it should, where the line between technology and the unknown has stopped being visible.
#
# The details are yours to fill in, because every version of this story is different, and every version is true.
#
# Let's go to find out what the signal says to you.

# %%
# Print the game directions to orient the player

# !pip install emoji

import emoji

print(f"""
{'='*71}
        {emoji.emojize(':magnifying_glass_tilted_left:')} {emoji.emojize(':magnifying_glass_tilted_left:')} Input here to personalize this story for you {emoji.emojize(':magnifying_glass_tilted_left:')} {emoji.emojize(':magnifying_glass_tilted_left:')} 
{'='*71}
""")

#data collecting and data defining
city_name = input(prompt="Enter the name of your favourite city: ")
number = input(prompt="Enter a number: ")
adjective = input(prompt="Enter an adjective: ")
city_place = input(prompt="Enter a place in the city you choose: ")
technology = input(prompt="Enter the name of an technology: ")
character_name = input(prompt="Enter the name of the character: ")
industry = input(prompt="Enter an industry: ")
future_year = input(prompt="Enter a year in the future: ")
input(prompt="Press Enter to reveal the story")

print(f"""
    {'*'*50}
            {emoji.emojize(':spider:')} {emoji.emojize(':spider:')} THE SIGNAL THAT NAMED US {emoji.emojize(':spider:')} {emoji.emojize(':spider:')} 
    {'*'*50}
""")

#Paragraph1
print(emoji.emojize(f""" :satellite: It began in {city_name}, on a night when the sky looked wrong and everyone felt it but nobody said anything. A signal had been intercepted by a research station on the edge of the city; not a random frequency, not background noise, but something structured, something that repeated exactly every {number} seconds.The team was called in quietly, no official briefing, no explanation, just a location and a time. When they arrived, the room was already dark except for the screens, and on every screen was the same line of code, blinking.\nNobody had written it.\n"""))

#Paragraph2
print(emoji.emojize(f""" :brain: The five of them had never worked together before, which was exactly why they were chosen.There was no hierarchy, no shared history, and no assumptions, just five people who were each the best at one specific thing nobody else wanted to understand.They were {adjective} under pressure, which in this context was not a personality trait but a survival requirement.One of them specialized in signal decryption, another in behavioral pattern recognition,and the others filled the gaps that most teams never even notice exist.Together they were not a unit: they were a system, and systems do not panic.\n"""))

#Paragraph3
print(emoji.emojize(f""" :alien: The signal was traced back to {city_place}, a location that should have been abandoned for decades.What they found there was not ruins: it was infrastructure, operational and maintained,running on technology that matched nothing in any known database.At the center of it was {technology}, a device that responded only to human voice and seemed to already know the name of everyone in the room.The lead investigator, {character_name}, stepped forward and spoke first, which was either the bravest or the most reckless decision made that night,depending on who you ask. The device answered in perfect English, and its first word was a question.\n"""))

#Paragraph4
print(emoji.emojize(f""":warning: What {character_name} heard in that answer changed everything the team thought they knew about the signal,the station, and the reason they had been chosen specifically.They had 72 hours to decide whether to report what they found, destroy it, or follow where it was pointing.Whatever they chose, there would be no going back.The {industry} implications alone were enough to shut down the investigation from the outside if the wrong people found out too soon.By {future_year}, the world would either know what happened in that room, or the record would show that nothing happened at all.The team looked at each other, and without a single word, they made the same decision simultaneously."""))

from IPython.display import Image, display

display(Image(filename='WhatsApp Image 2026-06-02 at 18.34.41.jpeg'))
# Out:
# ...
#
# ...
#         🔍 🔍 Input here to personalize this story for you 🔍 🔍
# ...
#
# Enter the name of your favourite city: ff
# Enter a number: fff
# Enter an adjective: f
# Enter a place in the city you choose: f
# Enter the name of an technology: ff
# Enter the name of the character: f
# Enter an industry: f
# Enter a year in the future: f
# Press Enter to reveal the story
#
#     **************************************************
#             🕷️ 🕷️ THE SIGNAL THAT NAMED US 🕷️ 🕷️
#     **************************************************
#
# ...
